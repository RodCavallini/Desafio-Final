# %%
import pandas as pd
import numpy as np
import sqlite3
from datetime import datetime
from plyer import notification 
import requests

# %% [markdown]
# # Extração tabela bancos

# %%
import functions as f

# %%
bancos = f.get_url("https://brasilapi.com.br/api/banks/v1")

# %%
bancos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359 entries, 0 to 358
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ispb      359 non-null    object
#  1   name      357 non-null    object
#  2   code      348 non-null    float64
#  3   fullName  357 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 11.3+ KB

# %%
bancos[bancos['name'].isnull()]
# Out:
#     ispb name  code fullName
# 357       NaN   NaN      NaN
# 358       NaN   NaN      NaN

# %%
bancos=bancos.dropna(subset='name')

# %%
bancos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ispb      357 non-null    object
#  1   name      357 non-null    object
#  2   code      348 non-null    float64
#  3   fullName  357 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 13.9+ KB

# %%
bancos[bancos['code'].isnull()]
# Out:
#          ispb                                      name  code  \
# 2    00038121                                     Selic   NaN
# 3    00038166                                     Bacen   NaN
# 10   00394460                                       STN   NaN
# 40   02992335                              CIP SA Siloc   NaN
# 58   04391007  CAMARA INTERBANCARIA DE PAGAMENTOS - CIP   NaN
# 184  28719664                                 Balcão B3   NaN
# 185  29011780                                 CIP SA C3   NaN
# 285  54641030                                 Câmara B3   NaN
# 304  60934221                                 Câmbio B3   NaN
#
#                                  fullName
# 2         Banco Central do Brasil - Selic
# 3                 Banco Central do Brasil
# 10   Secretaria do Tesouro Nacional - STN
# 40                                CIP S.A
# 58                                CIP S.A
# 184                  Sistema do Balcão B3
# 185                               CIP S.A
# ...

# %%
bancos.fillna(0, inplace = True)
bancos
# Out:
#          ispb                        name   code  \
# 0    00000000          BCO DO BRASIL S.A.    1.0
# 1    00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2    00038121                       Selic    0.0
# 3    00038166                       Bacen    0.0
# 4    00122327       SANTINVEST S.A. - CFI  539.0
# ..        ...                         ...    ...
# 352  92856905            ADVANCED CC LTDA  117.0
# 353  92874270           BCO DIGIMAIS S.A.  654.0
# 354  92875780            WARREN CVMC LTDA  371.0
# 355  92894922              BANCO ORIGINAL  212.0
# 356  94968518                EFX CC LTDA.  289.0
#
#                                               fullName
# 0                                 Banco do Brasil S.A.
# 1                         BRB - BANCO DE BRASILIA S.A.
# 2                      Banco Central do Brasil - Selic
# 3                              Banco Central do Brasil
# 4    SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...
# ...

# %%
bancos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ispb      357 non-null    object
#  1   name      357 non-null    object
#  2   code      357 non-null    float64
#  3   fullName  357 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 13.9+ KB

# %% [markdown]
# # Extração tabela Pix

# %%
pix = f.get_url("https://brasilapi.com.br/api/pix/v1/participants/")
pix
# Out:
#          ispb                                               nome  \
# 0    00000000                               BANCO DO BRASIL S.A.
# 1    00000208                       BRB - BANCO DE BRASILIA S.A.
# 2    00068987  COOPERATIVA DE CRÉDITO ARACREDI LTDA. - SICOOB...
# 3    00075847  COOPERATIVA DE CRÉDITO UNICRED CENTRO-SUL LTDA...
# 4    00106180  CENTRAL DAS COOPERATIVAS DE CRÉDITO DOS ESTADO...
# ..        ...                                                ...
# 829  95213211  COOPERATIVA DE CRéDITO, POUPANçA E INVESTIMENT...
# 830  95424891  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
# 831  95594941  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
# 832  97259253  COOPERATIVA E ECONOMIA E CRÉDITO MÚTUO DOS MÉD...
# 833  97489280  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
#
#                                          nome_reduzido  \
# 0                                   BCO DO BRASIL S.A.
# 1                           BRB - BCO DE BRASILIA S.A.
# ...

# %%
pix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 834 entries, 0 to 833
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ispb                     834 non-null    object
#  1   nome                     834 non-null    object
#  2   nome_reduzido            834 non-null    object
#  3   modalidade_participacao  834 non-null    object
#  4   tipo_participacao        834 non-null    object
#  5   inicio_operacao          834 non-null    object
# dtypes: object(6)
# memory usage: 39.2+ KB

# %%
pix['inicio_operacao'] = pd.to_datetime(pix['inicio_operacao'])
pix['inicio_operacao'] = pix["inicio_operacao"].dt.strftime('%d/%m/%Y')

# %%
pix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 834 entries, 0 to 833
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ispb                     834 non-null    object
#  1   nome                     834 non-null    object
#  2   nome_reduzido            834 non-null    object
#  3   modalidade_participacao  834 non-null    object
#  4   tipo_participacao        834 non-null    object
#  5   inicio_operacao          834 non-null    object
# dtypes: object(6)
# memory usage: 39.2+ KB

# %%
pix
# Out:
#          ispb                                               nome  \
# 0    00000000                               BANCO DO BRASIL S.A.
# 1    00000208                       BRB - BANCO DE BRASILIA S.A.
# 2    00068987  COOPERATIVA DE CRÉDITO ARACREDI LTDA. - SICOOB...
# 3    00075847  COOPERATIVA DE CRÉDITO UNICRED CENTRO-SUL LTDA...
# 4    00106180  CENTRAL DAS COOPERATIVAS DE CRÉDITO DOS ESTADO...
# ..        ...                                                ...
# 829  95213211  COOPERATIVA DE CRéDITO, POUPANçA E INVESTIMENT...
# 830  95424891  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
# 831  95594941  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
# 832  97259253  COOPERATIVA E ECONOMIA E CRÉDITO MÚTUO DOS MÉD...
# 833  97489280  COOPERATIVA DE CRÉDITO, POUPANÇA E INVESTIMENT...
#
#                                          nome_reduzido  \
# 0                                   BCO DO BRASIL S.A.
# 1                           BRB - BCO DE BRASILIA S.A.
# ...

# %% [markdown]
# # Extração Tabela corretoras

# %%
corretoras = f.get_url("https://brasilapi.com.br/api/cvm/corretoras/v1")

# %%
corretoras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cnpj                      374 non-null    object
#  1   type                      374 non-null    object
#  2   nome_social               374 non-null    object
#  3   nome_comercial            374 non-null    object
#  4   status                    374 non-null    object
#  5   email                     374 non-null    object
#  6   telefone                  374 non-null    object
#  7   cep                       374 non-null    object
#  8   pais                      374 non-null    object
#  9   uf                        374 non-null    object
#  10  municipio                 374 non-null    object
#  11  bairro                    374 non-null    object
#  12  complemento               374 non-null    object
# ...

# %%
corretoras
# Out:
#                cnpj        type  \
# 0    76621457000185  CORRETORAS
# 1    33817677000176  CORRETORAS
# 2    10664027000132  CORRETORAS
# 3    44527444000155  CORRETORAS
# 4    33819590000138  CORRETORAS
# ..              ...         ...
# 369  01170892000131  CORRETORAS
# 370  61769790000169  CORRETORAS
# 371  92875780000131  CORRETORAS
# 372  24543688000114  CORRETORAS
# 373  02332886000104  CORRETORAS
#
#                                            nome_social      nome_comercial  \
# 0                                        4UM DTVM S.A.   4UM INVESTIMENTOS
# 1    ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES ...     ABC BRASIL DTVM
# 2                                   ABERTURA CCVM LTDA  ABERTURA CCVM LTDA
# 3    ABN AMRO CLEARING CORRETORA DE T-TULOS E VALOR...
# 4              AÇÃO S.A. CORRETORA DE VALORES E CÂMBIO         ACAO SA CVC
# ..                                                 ...                 ...
# ...
